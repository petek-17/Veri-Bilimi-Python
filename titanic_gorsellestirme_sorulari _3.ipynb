# %% [markdown]
# # 🎓 Titanic Veri Seti Görselleştirme Uygulamaları
# Her sorunun altında cevabınızı kodlayabilirsiniz.
# Grafiklerinizi yorumlamanız ve grafikten çıkarımlarınızı yazmanız gerekmektedir.

# %% [markdown]
# ## 🟢 Kolay Seviye

# %% [markdown]
# ### ❓ Soru: Cinsiyete göre yolcu sayısını görselleştirin. (örn. countplot veya bar chart)

# %%
# Cevabınızı buraya yazınız
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("titanic")

sex=df['sex'].value_counts()

plt.figure(figsize=(6,4))
plt.bar(sex.index,sex.values,color=['blue','pink'],width=0.5)
plt.title('Cinsiyete Göre Yolcu Sayısı')
plt.xlabel('Cinsiyet')
plt.ylabel('Yolcu Sayısı')
plt.grid(axis='y', linestyle='--', alpha=0.7) # Y ekseni için grid çizgileri
plt.tight_layout() # Grafik düzenini sıkıştır
plt.show()

# %% [markdown]
# ### ❓ Soru: "Survived" değişkeninin dağılımını çiziniz.

# %%
# Cevabınızı buraya yazınız
sns.countplot(x='survived', data=df)

plt.title('Survived Değişkeninin Dağılımı')
plt.xlabel('Survived (0 = Hayır, 1 = Evet)')
plt.ylabel('Kişi Sayısı')
plt.show()

# %% [markdown]
# ### ❓ Soru: "Pclass" değişkeninin histogramını veya çubuk grafiğini oluşturun.

# %%
# Cevabınızı buraya yazınız
plt.figure(figsize=(6,4))
plt.hist(df['pclass'], bins=[0.5, 1.5, 2.5, 3.5], edgecolor='black', rwidth=0.8)
plt.title('p class dağılımı')
plt.xlabel('Pclass (1 = 1. sınıf, 2 = 2. sınıf, 3 = 3. sınıf)')
plt.ylabel('frekanslar')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ❓ Soru: "Age" değişkeninin histogramını çiziniz.

# %%
# Cevabınızı buraya yazınız
plt.figure(figsize=(6,4))
plt.hist(df['age'], bins=20, edgecolor='black', rwidth=0.8)
plt.title('yaş dağılımı')
plt.xlabel('yaş')
plt.ylabel('frekanslar')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ❓ Soru: "Fare" değişkeninin histogramını çizip açıklayınız.

# %%
# Cevabınızı buraya yazınız
plt.figure(figsize=(10, 6))
sns.histplot(df['fare'], bins=40, kde=True, color='skyblue')

plt.title('Fare Değişkeninin Histogramı')
plt.xlabel('Ücret (Fare)')
plt.ylabel('Yolcu Sayısı')
plt.grid(True)
plt.show()

#coğu yolcu düşük ücretler ödemiştir.
#Bazı yolcular (1. sınıf) çok yüksek ücretler ödemiştir, bu da uçta birkaç büyük değere neden olur.
#Histogramın sağa çarpık (right-skewed) olması bu yüksek ücretli yolcuların etkisinden kaynaklanır

# %% [markdown]
# ## 🟡 Orta Seviye

# %% [markdown]
# ### ❓ Soru: Cinsiyete göre yaş dağılımını karşılaştırın. (örn. boxplot, violinplot, kdeplot)

# %%
# Cevabınızı buraya yazınız
sns.boxplot(x='sex',y='age',data=df)
plt.title("Cinsiyet ve Yaş İlişkisi") # Başlık ekle
plt.xlabel("Cinsiyet") # X eksenine etiket ekle
plt.ylabel("Yaş") # Y eksenine etiket ekle
plt.grid(True)
plt.show() # Grafiği göster

# %% [markdown]
# ### ❓ Soru: Pclass'a göre ücret dağılımını inceleyin.

# %%
# Cevabınızı buraya yazınız
sns.barplot(x="pclass", y="fare", data=df,palette="pastel") # Pclass ve yaş sütunlarını çubuk grafiği olarak çiz
plt.title("Ücret ve sınıf İlişkisi") # Başlık ekle
plt.xlabel("Pclass") # X eksenine etiket ekle
plt.ylabel("Ücret") # Y eksenine etiket ekle
plt.xticks(rotation=45) # X eksenindeki etiketleri döndür
plt.tight_layout() # Grafik düzenini sıkıştır
plt.show() # Grafiği göster
# Out:
# /tmp/ipython-input-25-4217533301.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="pclass", y="fare", data=df,palette="pastel") # Pclass ve yaş sütunlarını çubuk grafiği olarak çiz

# %% [markdown]
# ### ❓ Soru: Survived’a göre yaş dağılımını inceleyin.

# %%
# Cevabınızı buraya yazınız
sns.barplot(x="survived", y="age", data=df,palette="pastel") # Pclass ve yaş sütunlarını çubuk grafiği olarak çiz
plt.title("survived ve age İlişkisi") # Başlık ekle
plt.xlabel("hayatta kalma") # X eksenine etiket ekle
plt.ylabel("yaş") # Y eksenine etiket ekle
plt.xticks(rotation=30) # X eksenindeki etiketleri döndür
plt.tight_layout() # Grafik düzenini sıkıştır
plt.show() # Grafiği göster
# Out:
# /tmp/ipython-input-26-4053638310.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="survived", y="age", data=df,palette="pastel") # Pclass ve yaş sütunlarını çubuk grafiği olarak çiz

# %% [markdown]
# ### ❓ Soru: Cinsiyet ve sınıfa göre hayatta kalma oranlarını barplot ile karşılaştırın.

# %%
# Cevabınızı buraya yazınız
plt.figure(figsize=(10, 6))

sns.barplot(x="pclass", y="survived", hue="sex", data=df, palette="pastel")

plt.title("Cinsiyet ve Sınıfa Göre Hayatta Kalma Oranları")
plt.xlabel("Yolcu Sınıfı (Pclass)")
plt.ylabel("Hayatta Kalma Oranı")
plt.ylim(0, 1)  # Oranlar 0-1 aralığında
plt.grid(True, axis='y')

plt.show()

# %% [markdown]
# ### ❓ Soru: FacetGrid ile cinsiyete göre yaş histogramlarını ayrı ayrı gösterin.

# %%
# Cevabınızı buraya yazınız
g = sns.FacetGrid(df, col="sex") # FacetGrid ile hayatta kalma durumuna göre alt gruplar oluştur
g.map(sns.histplot, "age") # Her alt grupta yaş sütununu histogram olarak çiz

# %% [markdown]
# ### ❓ Soru: "Fare" ve "Age" değişkenleri arasında scatterplot oluşturun.

# %%
# Cevabınızı buraya yazınız
df_clean = df[["age", "fare"]]

plt.figure(figsize=(10, 6))
sns.scatterplot(x="age", y="fare", data=df_clean, alpha=0.6)

plt.title("Fare ve Age Değişkenleri Arasındaki İlişki (Scatterplot)")
plt.xlabel("Yaş")
plt.ylabel("Fare (Ücret)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### ❓ Soru: Korelasyon matrisi ve heatmap ile değişkenler arasındaki ilişkiyi görselleştirin.

# %%
# Cevabınızı buraya yazınız
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.title('KORELASYON')
plt.show()

# %% [markdown]
# ## 🔴 İleri Seviye

# %% [markdown]
# ### ❓ Soru: "Age" değişkeninin çarpıklık (skewness) ve basıklığını (kurtosis) hesaplayın ve yorumlayın.

# %%
# Cevabınızı buraya yazınız
from scipy.stats import skew, kurtosis
# Age sütunundaki eksik değerleri kaldır
age_data = df['age'].dropna()

# Çarpıklık ve basıklık hesapla
age_skew = skew(age_data)
age_kurt = kurtosis(age_data, fisher=True) # fisher=True ise normal dağılımda 0 verir

print(f"Çarpıklık (Skewness): {age_skew:.2f}")
print(f"Basıklık (Kurtosis): {age_kurt:.2f}")

#çarpıklık 0.39 gençlerden çok yaşlılar var.Ama çok belirgin değil, dağılım genel olarak simetrik sayılabilir.
#baskınlık 0.17 Yaşların çoğu ortalamaya yakın, ama biraz uç değer de var.
# Out:
# Çarpıklık (Skewness): 0.39
# Basıklık (Kurtosis): 0.17

# %% [markdown]
# ### ❓ Soru: Seaborn pairplot ile sayısal değişkenleri inceleyin. Hayatta kalma durumunu hue parametresiyle ayırın.

# %%
# Cevabınızı buraya yazınız
# Sadece sayısal değişkenleri seç
numeric_df = df.select_dtypes(include=["float64", "int64"])

# Eksik değerleri kaldır (pairplot çalışması için)
numeric_df = numeric_df.dropna()

# Orijinal survived bilgisi de gelsin
numeric_df["survived"] = df["survived"].loc[numeric_df.index]

# Pairplot çizimi
sns.pairplot(numeric_df, hue="survived", diag_kind="kde", palette="Set1")
plt.suptitle("Titanic Veri Seti – Sayısal Değişkenler ve Hayatta Kalma Durumu", y=1.02)
plt.show()
# Out:
# /tmp/ipython-input-8-4282462474.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_df["survived"] = df["survived"].loc[numeric_df.index]

# %% [markdown]
# ### ❓ Soru: "Sex", "Pclass" ve "Survived" değişkenlerini içeren gruplu bir violinplot oluşturun.

# %%
# Cevabınızı buraya yazınız
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x="pclass", y="age", hue="survived", split=True, inner="quart", palette="Set2")

plt.title("Sınıfa Göre Yaş ve Hayatta Kalma Dağılımı (Tüm Cinsiyetler)")
plt.xlabel("Yolcu Sınıfı (Pclass)")
plt.ylabel("Yaş")
plt.legend(title="Hayatta Kaldı mı")
plt.show()

# %% [markdown]
# ### ❓ Soru: "Embarked" değişkenine göre fare dağılımını inceleyin.

# %%
# Cevabınızı buraya yazınız
# Eksik değerleri temizle
df = df.dropna(subset=["fare", "embarked"])

# BOXPLOT ile ücret dağılımı
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x="embarked", y="fare", palette="pastel")
plt.title("Embarked (Liman) Değişkenine Göre Fare (Ücret) Dağılımı - Boxplot")
plt.xlabel("Biniş Limanı (Embarked)")
plt.ylabel("Bilet Ücreti (Fare)")
plt.show()
# Out:
# /tmp/ipython-input-11-1267616504.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="embarked", y="fare", palette="pastel")

# %% [markdown]
# ### ❓ Soru: Plotly ile cinsiyet ve sınıfa göre interaktif bir histogram oluşturun.

# %%
# Cevabınızı buraya yazınız
import plotly.express as px
# Eksik yaş verilerini kaldır
df = df.dropna(subset=["age", "sex", "pclass"])

# Plotly ile interaktif histogram
fig = px.histogram(
    df,
    x="age",#Histogramda yaş değişkenini gösteriyoruz.
    color="sex",#Cinsiyete göre renk ayrımı yapılıyor.
    facet_col="pclass",#Yolcu sınıfına göre sütunlarda ayrı histogramlar oluşturuluyor.
    category_orders={"pclass": [1, 2, 3]},
    labels={"age": "Yaş", "sex": "Cinsiyet", "pclass": "Sınıf"},
    title="Cinsiyet ve Sınıfa Göre Yaş Dağılımı (Titanic)",
    nbins=30, #Yaş aralığını 30 parçaya bölüyoruz.
    opacity=0.75
)

fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### ❓ Soru: Eksik veri analizi yaparak eksik verileri heatmap ile görselleştirin.

# %%
# Cevabınızı buraya yazınız

# Eksik verilerin durumu (True = eksik)
missing = df.isnull()

# Heatmap ile eksik verileri görselleştir
plt.figure(figsize=(12, 6))
sns.heatmap(missing, cbar=False, cmap="viridis", yticklabels=False)#cbar parametresi, ısı haritasının sağında çıkan **renk skalası (colorbar)**nın gösterilip gösterilmeyeceği.

plt.title("Titanic Veri Setinde Eksik Verilerin Heatmap Görselleştirmesi")
plt.xlabel("Değişkenler")
plt.show()

# %% [markdown]
# ### ❓ Soru: Cinsiyet ve yaş arasındaki ilişkiyi scatterplot ile gösterip renkleri hayatta kalma durumuna göre ayarlayın.

# %%
# Cevabınızı buraya yazınız
# Eksik yaş verilerini çıkar
df = df.dropna(subset=["age", "sex", "survived"])

# Scatterplot çizimi
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="sex", y="age", hue="survived", palette={0: "red", 1: "green"}, alpha=0.7)

plt.title("Cinsiyet ve Yaş Arasındaki İlişki (Hayatta Kalma Durumuna Göre)")
plt.xlabel("Cinsiyet")
plt.ylabel("Yaş")
plt.legend(title="Hayatta Kalma Durumu", labels=["Hayatta Kalamadı", "Hayatta Kaldı"])
plt.show()

# %% [markdown]
# ### ❓ Soru: Matplotlib ile özelleştirilmiş bir bar grafiği oluşturun (renk, kalınlık, grid, label).

# %%
# Cevabınızı buraya yazınız
# Sınıf bazında yolcu sayısı
# Cinsiyete göre hayatta kalan sayısı
survived_counts = df[df['survived'] == 1]['sex'].value_counts()

plt.figure(figsize=(6,4))

bars = plt.bar(survived_counts.index, survived_counts.values, color=['purple', 'orange'],
               linewidth=2, edgecolor='black')

plt.title('Cinsiyete Göre Hayatta Kalanlar', fontsize=14)
plt.xlabel('Cinsiyet', fontsize=12)
plt.ylabel('Hayatta Kalan Sayısı', fontsize=12)
plt.show()

# %% [markdown]
# ## 📘 Bonus Yorumlama Soruları

# %% [markdown]
# ### ❓ Soru: Korelasyonu yüksek olan iki değişken bulun. İlişkilerini grafikle açıklayın.

# %%
# Cevabınızı buraya yazınız
# Sayısal sütunları seçelim
numeric_df = df.select_dtypes(include='number')

# Korelasyon matrisini hesapla
corr = numeric_df.corr()

# Korelasyon matrisini görselleştir
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Sayısal Değişkenler Arasındaki Korelasyon")
plt.show()


#pclass ile survived arasındaki korelasyon:-0.34

#Bu, negatif yönlü ve orta zayıflıkta bir korelasyon anlamına gelir. Yani:

#Pclass arttıkça (yani 1. sınıftan 3. sınıfa gittikçe),Hayatta kalma olasılığı azalıyor.

# %% [markdown]
# ### ❓ Soru: En fazla hayatta kalan grup hangisidir? (Cinsiyet + Sınıf)

# %%
# Cevabınızı buraya yazınız
# Cinsiyet ve sınıfa göre grupla, hayatta kalanların sayısını hesapla
grouped = df.groupby(['sex', 'pclass'])['survived'].sum().reset_index()

# Büyükten küçüğe sırala
grouped_sorted = grouped.sort_values(by='survived', ascending=False)

print(grouped_sorted)

# Grafik çizimi
plt.figure(figsize=(8,6))
sns.barplot(data=grouped, x='pclass', y='survived', hue='sex')
plt.title("Cinsiyet ve Sınıfa Göre Hayatta Kalan Sayısı")
plt.xlabel("Bilet Sınıfı (Pclass)")
plt.ylabel("Hayatta Kalan Kişi Sayısı")
plt.legend(title="Cinsiyet")
plt.tight_layout()
plt.show()
# Out:
#       sex  pclass  survived
# 0  female       1        91
# 2  female       3        72
# 1  female       2        70
# 5    male       3        47
# 3    male       1        45
# 4    male       2        17

# %% [markdown]
# ### ❓ Soru: Yaş dağılımı normal mi? Neden?

# %%
# Cevabınızı buraya yazınız
age_data = df['age'].dropna()

plt.figure(figsize=(8,6))
sns.histplot(age_data, kde=True, bins=30, color='skyblue')
plt.title("Yaş Dağılımı (Histogram + KDE)")
plt.xlabel("Yaş")
plt.ylabel("Frekans")
plt.show()

#Yaş dağılımı normal değildir. Histogramdan görüldüğü üzere dağılım sağa çarpıktır ve simetrik değildir.
#Yaşlar daha çok genç bireylerde yoğunlaşırken, ileri yaşlara doğru frekans azalmakta, bu da normal dağılıma aykırılık göstermektedir.
#KDE eğrisi de çan eğrisinden sapmalar içerir. Ayrıca, çocuk yaş grubunda ikinci bir tepe görülmektedir.

# %% [markdown]
# ### ❓ Soru: Violinplot ile boxplot’ın farkı nedir?

# %%
# Cevabınızı buraya yazınız
#boxplot: Verinin medyanı, çeyrekleri ve uç değerlerini gösterir. Dağılımın şeklini göstermez.

#Violinplot: Boxplot bilgilerini verir + verinin yoğunluk ve dağılım şekli hakkında detay sunar.

# %% [markdown]
# ### ❓ Soru: Grafiklerde dikkat edilmesi gereken 3 temel ipucu nedir?

# %%
# Cevabınızı buraya yazınız
#Anlaşılır ve sade tasarım: Gereksiz süslemelerden kaçınmak, grafik kolay okunmalı ve ne anlattığı hemen anlaşılmalı.
#Doğru eksen ve ölçek kullanımı: Ekseni net belirtmek, ölçeklendirme yanıltıcı olmasın. Eksen etiketleri ve birimleri eksiksiz olsun.
#Uygun grafik tipi seçimi: Verinizin türüne ve anlatmak istediğimiz mesaja göre grafik seçmek (örneğin dağılım için scatter, oran için pasta grafik gibi).

# %% [markdown]
# ## 🧠 Refleksiyon

# %% [markdown]
# **En çok şaşırdığınız veya dikkat çeken sonuç neydi? Görselleştirme size veriyle ilgili hangi içgörüleri sağladı?**

# %%
# Yorumunuzu buraya yazınız
# cinsiyetin hayatta kalma oranı üzerindeki etkisi oldu. Özellikle kadın yolcuların hayatta kalma oranının erkeklere göre çok daha yüksek çıkması çok belirgin.
#Görselleştirme ile sağladığım içgörüler:

#Hayatta kalma oranlarının sınıf ve cinsiyete göre dağılımı kolayca görülebiliyor. Örneğin 1. sınıf kadınların neredeyse tamamı kurtulurken, 3. sınıf erkeklerin büyük kısmı hayatını kaybetmiş.

#Yaş dağılımı grafikleri, hayatta kalanların genellikle daha genç veya çocuk olduğunu gösteriyor.

#Pclass ve survived arasındaki korelasyon, yolcuların sosyal statüsünün hayatta kalma ihtimalini nasıl etkilediğini ortaya koyuyor.
